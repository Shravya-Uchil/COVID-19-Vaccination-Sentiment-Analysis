# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import os
import time
from datetime import datetime, date, timedelta
import warnings

import preprocessor as p

import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from textblob import TextBlob

warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [Errno -2]
# [nltk_data]     Name or service not known>

# %%
tweets_df = pd.read_csv('../Data/vaccination_all_tweets.csv')
tweets_df.sort_values(by='date').reset_index(drop = True)
# Out:
#                         id                                          user_name  \
# 0      1337727767551553536                                   Daily News Egypt
# 1      1337728701820268544                                          City A.M.
# 2      1337732077278662657                                             mystic
# 3      1337732996380696578                                           KHuntson
# 4      1337733048914358272  Party politics isn't working for anyone, anywhere
# ...                    ...                                                ...
# 69713  1385236441777807363                                  Workout Solutions
# 69714  1385236473998450694                                  Workout Solutions
# 69715  1385236820854812676                                  Workout Solutions
# 69716  1385236855092822016                                  Workout Solutions
# 69717  1385236941180973057                                  Workout Solutions
#
#                         user_location  \
# 0                               Egypt
# 1                     London, England
# 2                                 NaN
# 3                               USA🇺🇸
# 4               Wales, United Kingdom
# ...                               ...
# 69713  Toronto, Canada  and Worldwide
# 69714  Toronto, Canada  and Worldwide
# 69715  Toronto, Canada  and Worldwide
# 69716  Toronto, Canada  and Worldwide
# 69717  Toronto, Canada  and Worldwide
#
#                                         user_description         user_created  \
# 0      Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
# 1      London's business newspaper - News, Opinion, a...  2009-06-09 13:53:06
# 2                 I believe in the goodness of humanity.  2020-05-20 10:57:00
# 3      RN, health educator, writer, researcher, wife,...  2014-01-31 01:25:24
# 4      No lie to another is respectful; no lie to you...  2016-08-03 20:11:00
# ...                                                  ...                  ...
# 69713  George Tsanis – Workout Solutions Health and F...  2010-09-20 17:01:08
# 69714  George Tsanis – Workout Solutions Health and F...  2010-09-20 17:01:08
# 69715  George Tsanis – Workout Solutions Health and F...  2010-09-20 17:01:08
# 69716  George Tsanis – Workout Solutions Health and F...  2010-09-20 17:01:08
# 69717  George Tsanis – Workout Solutions Health and F...  2010-09-20 17:01:08
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 0              278080           116              765           True
# 1               66224           603              771           True
# 2                  14           162             1341          False
# 3                2035          1672             6734          False
# 4                 761           504            33675          False
# ...               ...           ...              ...            ...
# 69713            1200           236             2182          False
# 69714            1200           236             2182          False
# 69715            1200           236             2182          False
# 69716            1200           236             2182          False
# 69717            1200           236             2182          False
#
#                       date                                               text  \
# 0      2020-12-12 11:55:28  #FDA authorizes #PfizerBioNTech #coronavirus v...
# 1      2020-12-12 11:59:10  Trump announces #vaccine rollout 'in less than...
# 2      2020-12-12 12:12:35  #CovidVaccine #Pfizer-BioNTech COVID-19 #Pfize...
# 3      2020-12-12 12:16:14  FACT SHEET FOR RECIPIENTS AND CAREGIVERS\n\n#P...
# 4      2020-12-12 12:16:27  @mirekR9 @sputnikvaccine @AstraZeneca it's the...
# ...                    ...                                                ...
# 69713  2021-04-22 14:17:58  @fordnation Canada politicizing #COVID19. Labo...
# 69714  2021-04-22 14:18:06  @CP24 Canada politicizing #COVID19. Laboratori...
# 69715  2021-04-22 14:19:29  EMBARRASSING Ontario is reporting 3682  cases ...
# 69716  2021-04-22 14:19:37  @fordnation EMBARRASSING Ontario is reporting ...
# 69717  2021-04-22 14:19:57  @celliottability EMBARRASSING Ontario is repor...
#
#                                                 hashtags              source  \
# 0               ['FDA', 'PfizerBioNTech', 'coronavirus']     Twitter Web App
# 1                                            ['vaccine']     Twitter Web App
# 2      ['CovidVaccine', 'Pfizer', 'PfizerBioNTech', '...  Twitter for iPhone
# 3                     ['PfizerBioNTech', 'CovidVaccine']     Twitter Web App
# 4                                     ['PfizerBioNTech']     Twitter Web App
# ...                                                  ...                 ...
# 69713               ['COVID19', 'SputnikV', 'Argentina']  Twitter for iPhone
# 69714               ['COVID19', 'SputnikV', 'Argentina']  Twitter for iPhone
# 69715                             ['COVID19', 'vaccine']  Twitter for iPhone
# 69716                                        ['COVID19']  Twitter for iPhone
# 69717                                        ['COVID19']  Twitter for iPhone
#
#        retweets  favorites  is_retweet
# 0             1          1       False
# 1             0          2       False
# 2             0          1       False
# 3             0          0       False
# 4             0          0       False
# ...         ...        ...         ...
# 69713         0          0       False
# 69714         0          0       False
# 69715         0          0       False
# 69716         0          0       False
# 69717         0          0       False
#
# [69718 rows x 16 columns]

# %%
tweets_df_final = tweets_df[['user_name', 'user_location', 'user_description',
                             'date', 'text', 'hashtags']]

# %%
tweets_df_final.head(10)
# Out:
#               user_name                user_location  \
# 0            Rachel Roh    La Crescenta-Montrose, CA
# 1           Albert Fong            San Francisco, CA
# 2              eli🇱🇹🇪🇺👌                     Your Bed
# 3         Charles Adler       Vancouver, BC - Canada
# 4  Citizen News Channel                          NaN
# 5                   Dee          Birmingham, England
# 6     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 7   Dr.Krutika Kuppalli                          NaN
# 8           Erin Despas                          NaN
# 9          Ch.Amjad Ali                    Islamabad
#
#                                     user_description                 date  \
# 0  Aggregator of Asian American news; scanning di...  2020-12-20 06:06:44
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2020-12-13 16:27:13
# 2                                     heil, hydra 🖐☺  2020-12-12 20:33:45
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  2020-12-12 20:23:59
# 4  Citizen News Channel bringing you an alternati...  2020-12-12 20:17:19
# 5  Gastroenterology trainee, Clinical Research Fe...  2020-12-12 20:11:42
# 6  End North Stream 2 now - the pipeline of corru...  2020-12-12 20:06:00
# 7  ID, Global Health, VHF, Pandemic Prep, Emergin...  2020-12-12 20:04:29
# 8  Designing&selling on Teespring. Like 90s Disne...  2020-12-12 20:01:16
# 9  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2020-12-12 19:30:33
#
#                                                 text  \
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  Facts are immutable, Senator, even when you're...
# 4  Explain to me again why we need a vaccine @Bor...
# 5  Does anyone have any useful advice/guidance fo...
# 6  it is a bit sad to claim the fame for success ...
# 7  There have not been many bright days in 2020 b...
# 8  Covid vaccine; You getting it?\n\n #CovidVacci...
# 9  #CovidVaccine \n\nStates will start getting #C...
#
#                                             hashtags
# 0                                 ['PfizerBioNTech']
# 1                                                NaN
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...
# 3                                                NaN
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']
# 5                                                NaN
# 6                                    ['vaccination']
# 7                    ['BidenHarris', 'Election2020']
# 8  ['CovidVaccine', 'covid19', 'PfizerBioNTech', ...
# 9  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...

# %%
extract_datetime = datetime.today().strftime('%Y%m%d_%H%M%S')
tweets_df_final.drop_duplicates(inplace = True)

# %%
tweets_df_final.head(10)
# Out:
#               user_name                user_location  \
# 0            Rachel Roh    La Crescenta-Montrose, CA
# 1           Albert Fong            San Francisco, CA
# 2              eli🇱🇹🇪🇺👌                     Your Bed
# 3         Charles Adler       Vancouver, BC - Canada
# 4  Citizen News Channel                          NaN
# 5                   Dee          Birmingham, England
# 6     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 7   Dr.Krutika Kuppalli                          NaN
# 8           Erin Despas                          NaN
# 9          Ch.Amjad Ali                    Islamabad
#
#                                     user_description                 date  \
# 0  Aggregator of Asian American news; scanning di...  2020-12-20 06:06:44
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2020-12-13 16:27:13
# 2                                     heil, hydra 🖐☺  2020-12-12 20:33:45
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  2020-12-12 20:23:59
# 4  Citizen News Channel bringing you an alternati...  2020-12-12 20:17:19
# 5  Gastroenterology trainee, Clinical Research Fe...  2020-12-12 20:11:42
# 6  End North Stream 2 now - the pipeline of corru...  2020-12-12 20:06:00
# 7  ID, Global Health, VHF, Pandemic Prep, Emergin...  2020-12-12 20:04:29
# 8  Designing&selling on Teespring. Like 90s Disne...  2020-12-12 20:01:16
# 9  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2020-12-12 19:30:33
#
#                                                 text  \
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  Facts are immutable, Senator, even when you're...
# 4  Explain to me again why we need a vaccine @Bor...
# 5  Does anyone have any useful advice/guidance fo...
# 6  it is a bit sad to claim the fame for success ...
# 7  There have not been many bright days in 2020 b...
# 8  Covid vaccine; You getting it?\n\n #CovidVacci...
# 9  #CovidVaccine \n\nStates will start getting #C...
#
#                                             hashtags
# 0                                 ['PfizerBioNTech']
# 1                                                NaN
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...
# 3                                                NaN
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']
# 5                                                NaN
# 6                                    ['vaccination']
# 7                    ['BidenHarris', 'Election2020']
# 8  ['CovidVaccine', 'covid19', 'PfizerBioNTech', ...
# 9  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...

# %%
tweets_df = tweets_df_final.copy()
tweets_df['text_cleaned'] = tweets_df['text'].apply(lambda x: p.clean(x))
# tweets_df['user_description_cleaned'] = tweets_df['user_description'].apply(lambda x: p.clean(x))

# %%
tweets_df.drop_duplicates(subset='text_cleaned', keep="first", inplace = True)
tweets_df.head(10)
# Out:
#               user_name                user_location  \
# 0            Rachel Roh    La Crescenta-Montrose, CA
# 1           Albert Fong            San Francisco, CA
# 2              eli🇱🇹🇪🇺👌                     Your Bed
# 3         Charles Adler       Vancouver, BC - Canada
# 4  Citizen News Channel                          NaN
# 5                   Dee          Birmingham, England
# 6     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 7   Dr.Krutika Kuppalli                          NaN
# 8           Erin Despas                          NaN
# 9          Ch.Amjad Ali                    Islamabad
#
#                                     user_description                 date  \
# 0  Aggregator of Asian American news; scanning di...  2020-12-20 06:06:44
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2020-12-13 16:27:13
# 2                                     heil, hydra 🖐☺  2020-12-12 20:33:45
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  2020-12-12 20:23:59
# 4  Citizen News Channel bringing you an alternati...  2020-12-12 20:17:19
# 5  Gastroenterology trainee, Clinical Research Fe...  2020-12-12 20:11:42
# 6  End North Stream 2 now - the pipeline of corru...  2020-12-12 20:06:00
# 7  ID, Global Health, VHF, Pandemic Prep, Emergin...  2020-12-12 20:04:29
# 8  Designing&selling on Teespring. Like 90s Disne...  2020-12-12 20:01:16
# 9  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2020-12-12 19:30:33
#
#                                                 text  \
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  Facts are immutable, Senator, even when you're...
# 4  Explain to me again why we need a vaccine @Bor...
# 5  Does anyone have any useful advice/guidance fo...
# 6  it is a bit sad to claim the fame for success ...
# 7  There have not been many bright days in 2020 b...
# 8  Covid vaccine; You getting it?\n\n #CovidVacci...
# 9  #CovidVaccine \n\nStates will start getting #C...
#
#                                             hashtags  \
# 0                                 ['PfizerBioNTech']
# 1                                                NaN
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...
# 3                                                NaN
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']
# 5                                                NaN
# 6                                    ['vaccination']
# 7                    ['BidenHarris', 'Election2020']
# 8  ['CovidVaccine', 'covid19', 'PfizerBioNTech', ...
# 9  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...
#
#                                         text_cleaned
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2       Russian vaccine is created to last -4 years…
# 3  Facts are immutable, Senator, even when you're...
# 4          Elain to me again why we need a vaccine …
# 5  Does anyone have any useful advice/guidance fo...
# 6  it is a bit sad to claim the fame for success ...
# 7  There have not been many bright days in but he...
# 8                     Covid vaccine; You getting it?
# 9           States will start getting Monday, says …

# %%
punct =['%','/',':','\\','&amp;','&',';']

def remove_punctuations(text):
    for punctuation in punct:
        text = text.replace(punctuation, '')
    return text

tweets_df['text_cleaned'] = tweets_df['text_cleaned'].apply(lambda x: remove_punctuations(x))

# %%
tweets_df['text_cleaned'].replace('', np.nan, inplace=True)
tweets_df['text_cleaned'].replace(' ', np.nan, inplace=True)
tweets_df.dropna(subset=['text_cleaned'], inplace=True)
len(tweets_df)
# Out:
# 63894

# %%
tweets_df = tweets_df.reset_index(drop=True)
tweets_df.head(10)
# Out:
#               user_name                user_location  \
# 0            Rachel Roh    La Crescenta-Montrose, CA
# 1           Albert Fong            San Francisco, CA
# 2              eli🇱🇹🇪🇺👌                     Your Bed
# 3         Charles Adler       Vancouver, BC - Canada
# 4  Citizen News Channel                          NaN
# 5                   Dee          Birmingham, England
# 6     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 7   Dr.Krutika Kuppalli                          NaN
# 8           Erin Despas                          NaN
# 9          Ch.Amjad Ali                    Islamabad
#
#                                     user_description                 date  \
# 0  Aggregator of Asian American news; scanning di...  2020-12-20 06:06:44
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2020-12-13 16:27:13
# 2                                     heil, hydra 🖐☺  2020-12-12 20:33:45
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  2020-12-12 20:23:59
# 4  Citizen News Channel bringing you an alternati...  2020-12-12 20:17:19
# 5  Gastroenterology trainee, Clinical Research Fe...  2020-12-12 20:11:42
# 6  End North Stream 2 now - the pipeline of corru...  2020-12-12 20:06:00
# 7  ID, Global Health, VHF, Pandemic Prep, Emergin...  2020-12-12 20:04:29
# 8  Designing&selling on Teespring. Like 90s Disne...  2020-12-12 20:01:16
# 9  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2020-12-12 19:30:33
#
#                                                 text  \
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  Facts are immutable, Senator, even when you're...
# 4  Explain to me again why we need a vaccine @Bor...
# 5  Does anyone have any useful advice/guidance fo...
# 6  it is a bit sad to claim the fame for success ...
# 7  There have not been many bright days in 2020 b...
# 8  Covid vaccine; You getting it?\n\n #CovidVacci...
# 9  #CovidVaccine \n\nStates will start getting #C...
#
#                                             hashtags  \
# 0                                 ['PfizerBioNTech']
# 1                                                NaN
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...
# 3                                                NaN
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']
# 5                                                NaN
# 6                                    ['vaccination']
# 7                    ['BidenHarris', 'Election2020']
# 8  ['CovidVaccine', 'covid19', 'PfizerBioNTech', ...
# 9  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...
#
#                                         text_cleaned
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2       Russian vaccine is created to last -4 years…
# 3  Facts are immutable, Senator, even when you're...
# 4          Elain to me again why we need a vaccine …
# 5  Does anyone have any useful adviceguidance for...
# 6  it is a bit sad to claim the fame for success ...
# 7  There have not been many bright days in but he...
# 8                      Covid vaccine You getting it?
# 9           States will start getting Monday, says …

# %%
def get_value_counts(col_name, analyzer_name):
    count = pd.DataFrame(tweets_df[col_name].value_counts())
    percentage = pd.DataFrame(tweets_df[col_name].value_counts(normalize=True).mul(100))
    value_counts_df = pd.concat([count, percentage], axis = 1)
    value_counts_df = value_counts_df.reset_index()
    value_counts_df.columns = ['sentiment', 'counts', 'percentage']
    value_counts_df.sort_values('sentiment', inplace = True)
    value_counts_df['percentage'] = value_counts_df['percentage'].apply(lambda x: round(x,2))
    value_counts_df = value_counts_df.reset_index(drop = True)
    value_counts_df['analyzer'] = analyzer_name
    return value_counts_df

# %%
tweets_df['textblob_score'] = tweets_df['text_cleaned'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
neutral_thresh = 0.05

# %%
tweets_df['textblob_sentiment'] = tweets_df['textblob_score'].apply(lambda c: 'Positive' if c >= neutral_thresh else ('Negative' if c <= -(neutral_thresh) else 'Neutral'))

# %%
tweets_df['textblob_score'].describe()
# Out:
# count    63894.000000
# mean         0.104073
# std          0.247993
# min         -1.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.233333
# max          1.000000
# Name: textblob_score, dtype: float64

# %%
textblob_sentiment_df = get_value_counts('textblob_sentiment','TextBlob')
textblob_sentiment_df
# Out:
#   sentiment  counts  percentage  analyzer
# 0  Negative    7058       11.05  TextBlob
# 1   Neutral   31767       49.72  TextBlob
# 2  Positive   25069       39.24  TextBlob

# %%
sns.set_theme(style="dark")
ax = sns.barplot(x="sentiment", y="percentage", data=textblob_sentiment_df)
ax.set_title('TextBlob')

for index, row in textblob_sentiment_df.iterrows():
    ax.text(row.name,row.percentage, round(row.percentage,1), color='black', ha="center")
